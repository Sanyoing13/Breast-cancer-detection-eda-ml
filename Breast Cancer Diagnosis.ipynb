# %% [markdown]
# ## **Breast Cancer Diagnosis: EDA and Predictive Modeling**

# %% [markdown]
# This project analyses a breast cancer dataset using Exploratory Data Analysis (EDA) and Machine Learning to build a model that predicts whether a tumor is malignant or benign based on features derived from digitized image of a breast mass.

# %% [markdown]
# **Objective**

# %% [markdown]
# To identify important patterns in the data and build a reliable classification model to assist in early cancer detection.

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_breast_cancer

# %% [markdown]
# **Load and Convert the Dataset**

# %%
data = load_breast_cancer()

# %%
df = pd.DataFrame(data=data.data, columns=data.feature_names)
df['target'] = data.target

# %% [markdown]
# **Inspecting the Dataset**

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %% [markdown]
# **Check Target Distribution**

# %%
df['target'].value_counts()
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
sns.countplot(x='target', data=df)
plt.title('Target Distribution( 0 = Malignant, 1 = Benign)')
plt.show()

# %% [markdown]
# **Check Missing Values**

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %% [markdown]
# **Distribution of Selected Features**

# %%
features = ['mean radius', 'mean texture', 'mean area', 'mean smoothness']

for feature in features:
    plt.figure(figsize=(6,4))
    sns.histplot(data=df, x=feature, hue='target', kde=True)
    plt.title(f'{feature} Distribution by Target')
    plt.show()

# %% [markdown]
# **Boxplots to Detect Outliers**

# %%
plt.figure(figsize=(10,6))
sns.boxenplot(data=df[features])
plt.title('Boxplot of Selected Features')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Pairplot**

# %%
sns.pairplot(df[['mean radius', 'mean texture', 'mean area', 'mean smoothness', 'target']], hue='target')
plt.show()

# %% [markdown]
# ### **Feature Scaling:**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop('target', axis=1)
y = df['target']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# **Train_Test_Split:**

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.33, random_state=42)

# %%
len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (381, 188, 381, 188)

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
np.std(X_train_scaled).round()
# Out:
# 1.0

# %%
x1 = 15.46
x_mean = 14.18
std_x = 3.57

(x1-x_mean)/std_x
# Out:
# 0.3585434173669471

# %% [markdown]
# **Model Building**

# %% [markdown]
# Train and evaluate multiple models using standard classification metrics.

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %% [markdown]
# **Model Evaluation**

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, roc_auc_score, roc_curve, classification_report

# %%
sns.countplot(x = y)
plt.show()

# %%
acc_sc = accuracy_score(y_test, y_pred)
rec_sc = recall_score(y_test, y_pred)
prec_sc = precision_score(y_test, y_pred)
cr = classification_report(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

# %%
print(f"accuracy_score: {acc_sc}\nrecall_sore: {rec_sc}\nprecision score:\n{prec_sc}\nclassification_report:\n{cr}\nconfusion_matrix:\n{cm}")
# Out:
# accuracy_score: 0.9946808510638298
# recall_sore: 1.0
# precision score:
# 0.9918032786885246
# classification_report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        67
#            1       0.99      1.00      1.00       121
#
#     accuracy                           0.99       188
#    macro avg       1.00      0.99      0.99       188
# weighted avg       0.99      0.99      0.99       188
#
# confusion_matrix:
# [[ 66   1]
#  [  0 121]]

# %% [markdown]
# **The model is a good fit since all scores are around 99%.**

# %%
ras = roc_auc_score(y_test, y_pred)

# %%
ras
# Out:
# 0.9925373134328358

# %% [markdown]
# **A area-under-curve (AUC) score oof 0.99 indicates a good model.**
#
# roc_auc_score measures overall model discrimination ability. **Value around 0.5 means NO Discrimination. Value > 0.7 is considered as good.**

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
plt.figure(figsize=(4,2))
plt.plot(fpr, tpr)
plt.plot([0,1], [0,1])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.show()

# %% [markdown]
# **Since the roc curve is above the diagonal and closer to y-axis, it implies higher tpr for the given thresholds, hence is a good fit.**

# %%
coef = pd.Series(model.coef_[0], index = X.columns)
np.exp(coef)
# Out:
# mean radius                0.694264
# mean texture               0.685531
# mean perimeter             0.707654
# mean area                  0.665322
# mean smoothness            0.922190
# mean compactness           1.884668
# mean concavity             0.450887
# mean concave points        0.335597
# mean symmetry              1.173972
# mean fractal dimension     1.133626
# radius error               0.307758
# texture error              1.245980
# perimeter error            0.489458
# area error                 0.444449
# smoothness error           0.812622
# compactness error          1.714668
# concavity error            1.043137
# concave points error       0.647465
# symmetry error             1.648038
# fractal dimension error    1.804260
# worst radius               0.466579
# worst texture              0.277142
# worst perimeter            0.567313
# worst area                 0.492589
# worst smoothness           0.587836
# worst compactness          1.101457
# ...

# %% [markdown]
# - A value of np.exp(coef) < 1 implies that the probability of positive class reduces by 1-np.exp(coef).
# - On the other hand a value > 1 implies that the pprobability of positive class increases by np.exp(coef)-1.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_entropy = DecisionTreeClassifier(criterion="entropy", random_state=42)

# %%
dt_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
y_pred_entropy = dt_entropy.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve

# %%
cr_ent = classification_report(y_test, y_pred_entropy)
cm_ent = confusion_matrix(y_test, y_pred_entropy)

print(cr_ent, cm_ent)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92        67
#            1       0.94      0.98      0.96       121
#
#     accuracy                           0.95       188
#    macro avg       0.95      0.93      0.94       188
# weighted avg       0.95      0.95      0.95       188
#  [[ 59   8]
#  [  2 119]]

# %% [markdown]
# **Conclusion**
#
# - The dataset is clean with no missing values.
# - Logistic Regression achieved high accuracy and ROC-AUC.
# - Feature scaling was crucial for performance.
# - Further improvements can be made using ensemble models or hyperparameter tuning.
